# %%
import  pandas as pd
import csv
import pyodbc

import pandas as pd
from sqlalchemy import create_engine, MetaData, Table, select
from six.moves import urllib


cnxn = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                      "Server=PEPWDS01340\SQLITGECMETA1T, 60108;"
                      "Database=MDM;"
                      "Trusted_Connection=yes;")

# %%
cursor = cnxn.cursor()

# %%
df=pd.read_csv('load1.csv')
df.to_csv('load1_new.csv',index=False,header=False,quoting=csv.QUOTE_NONNUMERIC)
df
# Out:
#     UPCMasterId          UPC  \
# 0             3   4000046411
# 1             6   4138761215
# 2          1142  81829001208
# 3          2125   2190881263
# 4          3379   7349013041
# 5          1143  89470001051
# 6          1145  89470001049
# 7             2   4000001603
# 8             5   4138752458
# 9          2122   2190881266
# 10         2126  85277200106
# 11         1152  81829001424
# 12         1153  81829001249
# 13         3380   7349000000
# 14            1   4000042208
# 15         1141  81829001209
# 16         1151  89470001020
# 17         3383   7349012354
# 18         3385   7349013042
# 19         3386   7349012884
# 20           10   4138711160
# 21           12   4138792985
# 22           15   4138711294
# 23           18   4138723442
# 24           19   4138700530
# 25           21   4138722730
# 26           24   4138700500
# 27            4   4000016468
# 28         2123   2190881262
# 29         2124  85277200104
# 30         1144  89470001052
# ...

# %%
import sqlalchemy
params = urllib.parse.quote_plus("DRIVER={SQL Server Native Client 11.0};SERVER=PEPWDS01340\SQLITGECMETA1T, 60108;DATABASE=MDM;Trusted_Connection=yes;")
engine = sqlalchemy.create_engine("mssql+pyodbc:///?odbc_connect=%s" % params) 
engine.connect() 
# suppose df is the data-frame that we want to insert in database
df.to_sql(name='dbo.TEST2_MDM_UPC',con=engine, index=False, if_exists='append')
