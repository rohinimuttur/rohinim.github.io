# %%
import pandas as pd
import numpy as np

dfnew=pd.read_csv('CitiBikeWebApp/input/citibike_data_sample_test1.csv')

dfnew['birth year'] = pd.to_numeric(dfnew['birth year'], errors='coerce')

dfnew['birth year']=dfnew['birth year'].astype(int)
dfnew['birth year']
# Out:
# 0       1989
# 1       1988
# 2       1985
# 3       1982
# 4       1983
# 5       1987
# 6       1985
# 7       1990
# 8       1986
# 9       1996
# 10      1996
# 11      1981
# 12      1988
# 13      1983
# 14      1990
# 15      1987
# 16      1987
# 17      1988
# 18      1982
# 19      1991
# 20      1985
# 21      1987
# 22      1982
# 23      1988
# 24      1986
# 25      1985
# 26      1982
# 27      1992
# 28      1986
# 29      1984
#         ...
# 1969    1986
# 1970    1981
# 1971    1992
# 1972    1985
# 1973    1986
# 1974    1993
# 1975    1994
# 1976    1987
# 1977    1990
# 1978    1993
# 1979    1982
# 1980    1989
# 1981    1984
# 1982    1980
# 1983    1986
# 1984    1981
# 1985    1983
# 1986    1990
# 1987    1982
# 1988    1989
# 1989    1985
# 1990    1982
# 1991    1991
# 1992    1989
# 1993    1980
# 1994    1984
# 1995    1988
# 1996    1985
# 1997    1981
# 1998    1987
# Name: birth year, Length: 1999, dtype: int32

# %%
dfnew.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'tripduration', 'starttime', 'stoptime',
#        'start station id', 'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'lat_dist', 'lon_dist', 'lat_miles',
#        'lon_miles', 'totaldistance', 'Speed', 'date', 'Time_day', 'age',
#        'weight', 'calories_burned'],
#       dtype='object')

# %%
dfnew.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  tripduration                starttime  \
# 0           0      19019865        1957.0  2016-06-24 19:40:13.000
# 1           1      23619339         764.0  2015-08-26 08:54:44.000
# 2           2       7739281         511.0  2018-01-10 16:52:30.195
# 3           3      22837086         380.0  2015-08-05 16:43:32.000
# 4           4       6318397         188.0  2015-12-15 19:19:55.000
#
#                    stoptime  start station id       start station name  \
# 0        6/24/2016 20:12:50             368.0       Carmine St & 6 Ave
# 1        8/26/2015 09:07:29             450.0          W 49 St & 8 Ave
# 2  2018-01-10 17:01:02.1460             527.0          E 33 St & 2 Ave
# 3         8/5/2015 16:49:52             517.0    Pershing Square South
# 4       12/15/2015 19:23:03             410.0  Suffolk St & Stanton St
#
#    start station latitude  start station longitude  end station id  ...  \
# ...

# %%
del dfnew['end station id']

# %%
dfnew.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station name',
#        'start station latitude', 'start station longitude', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'lat_dist', 'lon_dist', 'lat_miles',
#        'lon_miles', 'totaldistance', 'Speed', 'date', 'Time_day', 'age',
#        'weight', 'calories_burned'],
#       dtype='object')

# %%
dfnew['age']
# Out:
# 0       20-39
# 1       20-39
# 2       20-39
# 3       20-39
# 4       20-39
# 5       20-39
# 6       20-39
# 7       20-39
# 8       20-39
# 9       20-39
# 10      20-39
# 11      20-39
# 12      20-39
# 13      20-39
# 14      20-39
# 15      20-39
# 16      20-39
# 17      20-39
# 18      20-39
# 19      20-39
# 20      20-39
# 21      20-39
# 22      20-39
# 23      20-39
# 24      20-39
# 25      20-39
# 26      20-39
# 27      20-39
# 28      20-39
# 29      20-39
#         ...
# 1969    20-39
# 1970    20-39
# 1971    20-39
# 1972    20-39
# 1973    20-39
# 1974    20-39
# 1975    20-39
# 1976    20-39
# 1977    20-39
# 1978    20-39
# 1979    20-39
# 1980    20-39
# 1981    20-39
# 1982    20-39
# 1983    20-39
# 1984    20-39
# 1985    20-39
# 1986    20-39
# 1987    20-39
# 1988    20-39
# 1989    20-39
# 1990    20-39
# 1991    20-39
# 1992    20-39
# 1993    20-39
# 1994    20-39
# 1995    20-39
# 1996    20-39
# 1997    20-39
# 1998    20-39
# ...

# %%
dataset=dfnew.to_json(orient='records')

# %%
dataset
# Out:
# '[{"tripduration":1957,"starttime":"6\\/24\\/2016 19:40","stoptime":"6\\/24\\/2016 20:12","start_station_id":368,"start_station_name":"Carmine St & 6 Ave","start_station_latitude":40.73038599,"start_station_longitude":-74.00214988,"end_station_id":2002,"end_station_name":"Wythe Ave & Metropolitan Ave","end_station_latitude":40.716887,"end_station_longitude":-73.963198,"bikeid":18668,"usertype":"Subscriber","birth_year":1989.0,"gender":1},{"tripduration":764,"starttime":"8\\/26\\/2015 8:54","stoptime":"8\\/26\\/2015 9:07","start_station_id":450,"start_station_name":"W 49 St & 8 Ave","start_station_latitude":40.76227205,"start_station_longitude":-73.98788205,"end_station_id":402,"end_station_name":"Broadway & E 22 St","end_station_latitude":40.7403432,"end_station_longitude":-73.98955109,"bikeid":17339,"usertype":"Subscriber","birth_year":1988.0,"gender":1},{"tripduration":511,"starttime":"52:30.2","stoptime":"01:02.1","start_station_id":527,"start_station_name":"E 33 St & 2 Ave","star
# ...

# %%
# Out:
#      tripduration         starttime          stoptime  start_station_id  \
# 81           1966           24:51.1           57:37.4              3322
# 33           1120           54:03.6           12:44.2              3358
# 139           484    3/5/2017 15:40    3/5/2017 15:49              3330
# 168           913           33:36.4           48:50.0              3676
# 71            626           04:09.2           14:35.9              3571
# 79            137   6/12/2017 22:38   6/12/2017 22:41               436
# 59            628  11/25/2017 13:50  11/25/2017 14:00                83
# 160           311    7/7/2017 14:55    7/7/2017 15:00               241
# 112          1381    5/16/2014 8:01    5/16/2014 8:24               157
# 38            352   6/28/2017 17:55   6/28/2017 18:01              3242
# 136          1523   1/21/2015 14:41   1/21/2015 15:07               233
# 148           544   7/27/2017 21:22   7/27/2017 21:31               392
# ...

# %%
dfnew=dfnew.dropna()
dfnew['birth_year']=dfnew['birth_year'].astype(int)

# %%
dfnew=dfnew.sort_values(by=['start_station_latitude'],ascending=[True])

# %%
dfnew
# Out:
#      tripduration         starttime          stoptime  start_station_id  \
# 81           1966           24:51.1           57:37.4              3322
# 33           1120           54:03.6           12:44.2              3358
# 139           484    3/5/2017 15:40    3/5/2017 15:49              3330
# 168           913           33:36.4           48:50.0              3676
# 71            626           04:09.2           14:35.9              3571
# 79            137   6/12/2017 22:38   6/12/2017 22:41               436
# 59            628  11/25/2017 13:50  11/25/2017 14:00                83
# 160           311    7/7/2017 14:55    7/7/2017 15:00               241
# 112          1381    5/16/2014 8:01    5/16/2014 8:24               157
# 136          1523   1/21/2015 14:41   1/21/2015 15:07               233
# 148           544   7/27/2017 21:22   7/27/2017 21:31               392
# 8            1853  12/17/2016 22:32  12/17/2016 23:03               313
# ...

# %%
bikedf=pd.read_csv('CitiBikeWebApp/input/citibike_data_sample_improved.csv')
bikedf.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  tripduration                starttime  \
# 0           0      19019865        1957.0  2016-06-24 19:40:13.000
# 1           1      23619339         764.0  2015-08-26 08:54:44.000
# 2           2       7739281         511.0  2018-01-10 16:52:30.195
# 3           3      22837086         380.0  2015-08-05 16:43:32.000
# 4           4       6318397         188.0  2015-12-15 19:19:55.000
#
#                    stoptime  start station id       start station name  \
# 0        6/24/2016 20:12:50             368.0       Carmine St & 6 Ave
# 1        8/26/2015 09:07:29             450.0          W 49 St & 8 Ave
# 2  2018-01-10 17:01:02.1460             527.0          E 33 St & 2 Ave
# 3         8/5/2015 16:49:52             517.0    Pershing Square South
# 4       12/15/2015 19:23:03             410.0  Suffolk St & Stanton St
#
#    start station latitude  start station longitude  end station id  ...  \
# ...

# %%
#bikedf['birth year']=bikedf['birth year'].astype(int)
bikedf=bikedf.dropna()
bikedf['birth year']=bikedf['birth year'].astype(int)
bikedf['birth year']
# Out:
# 0         1989
# 1         1988
# 2         1985
# 3         1982
# 4         1983
# 5         1987
# 6         1985
# 7         1990
# 8         1986
# 9         1996
# 10        1996
# 11        1981
# 12        1988
# 13        1983
# 14        1990
# 15        1987
# 16        1987
# 17        1988
# 18        1982
# 19        1991
# 20        1985
# 21        1987
# 22        1982
# 23        1988
# 24        1986
# 25        1985
# 26        1982
# 27        1992
# 28        1986
# 29        1984
#           ...
# 707799    1887
# 707800    1959
# 707801    1885
# 707802    1930
# 707803    1958
# 707804    1949
# 707805    1912
# 707806    1959
# 707807    1958
# 707808    1931
# 707809    1946
# 707810    1955
# 707811    1885
# 707812    1959
# 707813    1959
# 707814    1951
# 707815    1958
# 707816    1885
# 707817    1944
# 707818    1958
# 707819    1954
# 707820    1885
# 707821    1958
# 707822    1930
# 707823    1912
# 707824    1900
# 707825    1885
# ...

# %%
bikedf=bikedf.sort_values(by=['bikeid'],ascending=[True])

# %%
bikedf.to_csv('citibike_sample_test2.csv')

# %%
bikedf.count()
# Out:
# Unnamed: 0                 654108
# Unnamed: 0.1               654108
# tripduration               654108
# starttime                  654108
# stoptime                   654108
# start station id           654108
# start station name         654108
# start station latitude     654108
# start station longitude    654108
# end station id             654108
# end station name           654108
# end station latitude       654108
# end station longitude      654108
# bikeid                     654108
# usertype                   654108
# birth year                 654108
# gender                     654108
# lat_dist                   654108
# lon_dist                   654108
# lat_miles                  654108
# lon_miles                  654108
# totaldistance              654108
# Speed                      654108
# date                       654108
# Time_day                   654108
# age                        654108
# weight                     654108
# ...

# %%
sample_df1=bikedf.sample(frac=0.1)

# %%
sample_df1.count()
# Out:
# Unnamed: 0                 65411
# Unnamed: 0.1               65411
# tripduration               65411
# starttime                  65411
# stoptime                   65411
# start station id           65411
# start station name         65411
# start station latitude     65411
# start station longitude    65411
# end station id             65411
# end station name           65411
# end station latitude       65411
# end station longitude      65411
# bikeid                     65411
# usertype                   65411
# birth year                 65411
# gender                     65411
# lat_dist                   65411
# lon_dist                   65411
# lat_miles                  65411
# lon_miles                  65411
# totaldistance              65411
# Speed                      65411
# date                       65411
# Time_day                   65411
# age                        65411
# weight                     65411
# calories_burned            65411
# dtype: int64
