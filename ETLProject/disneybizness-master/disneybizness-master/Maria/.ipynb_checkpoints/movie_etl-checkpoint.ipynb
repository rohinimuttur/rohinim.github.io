# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
# !which chromedriver
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# which: no chromedriver in (/c/Users/rohin/bin:/mingw64/bin:/usr/local/bin:/usr/bin:/usr/bin:/mingw64/bin:/usr/bin:/c/Users/rohin/bin:/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/iCLS:/c/Program Files/Intel/Intel(R) Management Engine Components/iCLS:/c/Windows/system32:/c/Windows:/c/Windows/System32/Wbem:/c/Windows/System32/WindowsPowerShell/v1.0:/c/Windows/System32/OpenSSH:/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/DAL:/c/Program Files/Intel/Intel(R) Management Engine Components/DAL:/c/Program Files (x86)/Intel/Intel(R) Management Engine Components/IPT:/c/Program Files/Intel/Intel(R) Management Engine Components/IPT:/c/Program Files/Intel/WiFi/bin:/c/Program Files/Common Files/Intel/WirelessCommon:/cmd:/c/Program Files/Microsoft SQL Server/Client SDK/ODBC/130/Tools/Binn:/c/Program Files (x86)/Microsoft SQL Server/140/Tools/Binn:/c/Program Files/Microsoft SQL Server/140/Tools/Binn:/c/Program Files/Microsoft SQL Server/140/DTS/Binn:/c/Program Files (x86)/Microsoft SQL Server/Client SDK/ODBC/130/Tools/Binn:/c/Program Files (x86)/Microsoft SQL Server/140/DTS/Binn:/c/Program Files (x86)/Microsoft SQL Server/140/Tools/Binn/ManagementStudio:/c/Program Files/MySQL/MySQL Server 8.0/bin:/c/Program Files/MongoDB/Server/4.0/bin:/c/Users/rohin/Anaconda3:/c/Users/rohin/Anaconda3/Library/mingw-w64/bin:/c/Users/rohin/Anaconda3/Library/usr/bin:/c/Users/rohin/Anaconda3/Library/bin:/c/Users/rohin/Anaconda3/Scripts:/c/Users/rohin/AppData/Local/Microsoft/WindowsApps:/c/Program Files/heroku/bin:/c/Users/rohin/AppData/Local/Programs/Microsoft VS Code/bin:/c/Users/rohin/AppData/Local/GitHubDesktop/bin:/c/Program Files/MongoDB/Server/4.0/bin:/usr/bin/vendor_perl:/usr/bin/core_perl)

# %%
#url_disney = 'https://www.imdb.com/search/title-text?trivia=Disney+movie+'
url_disney = 'https://www.imdb.com/list/ls026785255/'
browser.visit(url_disney)
engine = create_engine("mysql://root:Shining$tar3@localhost/disney")
conn = engine.connect()
# html = browser.html
# soup = bs(html,"html.parser")

# all_movies = soup.find_all("div",class_="lister-item-content")
# df= pd.DataFrame()

for _ in range(0,2):

    html = browser.html
    soup = bs(html,"html.parser")

    all_movies = soup.find_all("div",class_="lister-item-content")
    df= pd.DataFrame()
    
    for movie in all_movies: 

        movie_title = movie.find("h3",class_="lister-item-header")
        if movie_title is not None:
            movie_title = movie_title.text.strip().replace('\n', ' ') #replace characters
            movie_split = movie_title.split(' ') #
            len_movie_split = len(movie_split)
            movie_title = ' '.join(movie_split[1:-1]) #extract the year and remove from title
            year = movie_split[-1] #grab the year from the movie
        metascore= movie.find("div", class_="inline-block ratings-metascore")
        if metascore is not None:
            metascore = metascore.text.strip().split(' ')[0]
        imdb = movie.find("span", class_="ipl-rating-star__rating")
        if imdb is not None:
            imdb = imdb.text.strip()


        #content_div = movie.find("div",class_="lister-item-content")
        url_extract = movie.find('a')['href']
        url_extract

        # append the link to the original website
        original_url = 'https://www.imdb.com'
        movie_url2 = original_url + url_extract


    #     print(f"Title: {movie_title}")
    #     print(f"Metascore: {metascore}")
    #     print(f"IMDB: {imdb}")
    #     print(f"link: {movie_url2}")

        data = {'Title': movie_title, 'year': year, 'Metascore': metascore, 'IMDB':imdb, 'link': movie_url2}
        x = pd.DataFrame(data,index = [0])
        df = pd.concat((df, x), axis=0)
        df.to_sql(name='imdbdisney', con=engine, if_exists='append', index=False)
    browser.click_link_by_partial_text("Next")

# %%
df
# Out:
#                                       Title    year Metascore IMDB  \
# 0           Snow White and the Seven Dwarfs  (1937)        95  7.6
# 0                                 Pinocchio  (1940)        99  7.5
# 0                                  Fantasia  (1940)        96  7.8
# 0                                     Dumbo  (1941)        96  7.3
# 0                                     Bambi  (1942)        91  7.3
# 0                 Victory Through Air Power  (1943)      None  6.7
# 0                      The Three Caballeros  (1944)        85  6.5
# 0                           Make Mine Music  (1946)        60  6.4
# 0                         Song of the South  (1946)        54  7.3
# 0                          Fun & Fancy Free  (1947)        66  6.7
# 0                               Melody Time  (1948)        69  6.5
# 0    The Adventures of Ichabod and Mr. Toad  (1949)        74  7.1
# 0                                Cinderella  (1950)        85  7.3
# 0                       Alice in Wonderland  (1951)        68  7.4
# 0                                 Peter Pan  (1953)        76  7.3
# 0                        Lady and the Tramp  (1955)        78  7.3
# 0                           Sleeping Beauty  (1959)        85  7.3
# 0                            101 Dalmatians  (1961)        83  7.2
# 0                    The Sword in the Stone  (1963)        61  7.2
# 0                           The Jungle Book  (1967)        65  7.6
# 0                            The Aristocats  (1970)        66  7.1
# 0                                Robin Hood  (1973)        57  7.6
# 0    The Many Adventures of Winnie the Pooh  (1977)      None  7.6
# 0                              The Rescuers  (1977)        74  6.9
# 0                     The Fox and the Hound  (1981)        65  7.3
# 0                        The Black Cauldron  (1985)        59  6.5
# 0                 The Great Mouse Detective  (1986)        73  7.2
# 0                   Who Framed Roger Rabbit  (1988)        83  7.7
# 0                          Oliver & Company  (1988)        58  6.7
# 0                        The Little Mermaid  (1989)        88  7.6
# ..                                      ...     ...       ...  ...
# 0                        Meet the Robinsons  (2007)        61  6.9
# 0                               Ratatouille  (2007)        96    8
# 0                                    WALL·E  (2008)        95  8.4
# 0                         Tinker Bell (2008  Video)      None  6.9
